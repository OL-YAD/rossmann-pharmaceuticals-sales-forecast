# %%
# Add the parent directory to the system path 
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, mean_squared_error
import os
import sys
sys.path.append(os.path.abspath(os.path.join('..')))

# %%
# importing modules from scripts 
from scripts.dl_final import *

# %%
# 1. Load and isolate the Rossmann Store Sales dataset into time series data
df_train = pd.read_csv('../data/clean/train.csv')  # Replace with your actual data file
# Out:
# C:\Users\JO\AppData\Local\Temp\ipykernel_22228\2790484199.py:2: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_train = pd.read_csv('../data/clean/train.csv')  # Replace with your actual data file

# %%
df_train['Date'] = pd.to_datetime(df_train['Date'])
data = df_train[['Date', 'Store', 'Sales']]

# Filter for a specific store (e.g., Store 1)
store_data = data[data['Store'] == 1]
store_data.set_index('Date', inplace=True)
store_data = store_data.resample('D').sum()

# %% [markdown]
# ### 2. Check whether your time Series Data is Stationary

# %%
# Check stationarity for a specific store
# Perform the ADF test

check_stationarity(store_data['Sales'])
# Out:
# ADF Statistic: -4.3681043682
# p-value: 0.0003378835
# Critical Values:
# 	1%: -3.4374778690
# 	5%: -2.8646866842
# 	10%: -2.5684454927
# The time series is stationary

# %%
# Difference the series (store_data is a Series, no need to reference 'Sales')
adf_result = adfuller(store_data['Sales'])
if adf_result[1] >= 0.05:
    store_data['Sales'] = store_data['Sales'].diff().dropna()

# %% [markdown]
# ### 4. Check for autocorrelation and partial autocorrelation of your data

# %%
# Autocorrelation and Partial Autocorrelation plots
fig, ax = plt.subplots(2, 1, figsize=(12, 8))
plot_acf(store_data['Sales'].dropna(), lags=30, ax=ax[0])
plot_pacf(store_data['Sales'].dropna(), lags=30, ax=ax[1])
plt.show()

# %% [markdown]
# ### 5. Transform the time series data into supervised learning data

# %%
# Define time steps
n_step = 30   # number of steps to use for prediction (30 days)
data_scaled = MinMaxScaler(feature_range=(-1, 1)).fit_transform(store_data['Sales'].values.reshape(-1, 1))
X, y = create_supervised_data(data_scaled, n_step)

# Reshape input to be [samples, n_steps, features]
X = X.reshape(X.shape[0], X.shape[1], 1)

# %% [markdown]
# ### 6. Scale your data in the (-1, 1) range

# %%
# Scale the data
scaler = MinMaxScaler(feature_range=(-1, 1))
data_scaled = scaler.fit_transform(store_data['Sales'].values.reshape(-1, 1))

# Create dataset for LSTM
X, y = create_supervised_data(data_scaled, n_step)
X = X.reshape(X.shape[0], X.shape[1], 1)

# %% [markdown]
# ### 7. Build an LSTM Regression model to predict the next sale

# %%
# Build and train the LSTM model
model = build_lstm_model(n_step)

# %%
### Train the model
history = train_lstm_model(model, X, y)
# Out:
# Epoch 1/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - loss: 0.1775 - val_loss: 0.1584
# Epoch 2/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1663 - val_loss: 0.1568
# Epoch 3/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1901 - val_loss: 0.1594
# Epoch 4/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1825 - val_loss: 0.1546
# Epoch 5/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1857 - val_loss: 0.1529
# Epoch 6/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1717 - val_loss: 0.1508
# Epoch 7/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1724 - val_loss: 0.1520
# Epoch 8/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1831 - val_loss: 0.1551
# Epoch 9/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1903 - val_loss: 0.1536
# Epoch 10/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1797 - val_loss: 0.1535
# Epoch 11/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1940 - val_loss: 0.1512
# Epoch 12/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1805 - val_loss: 0.1504
# Epoch 13/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1652 - val_loss: 0.1484
# Epoch 14/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1886 - val_loss: 0.1473
# Epoch 15/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1702 - val_loss: 0.1481
# Epoch 16/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1825 - val_loss: 0.1514
# Epoch 17/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1899 - val_loss: 0.1478
# Epoch 18/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1833 - val_loss: 0.1473
# Epoch 19/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1712 - val_loss: 0.1429
# Epoch 20/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1654 - val_loss: 0.1386
# Epoch 21/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1686 - val_loss: 0.1448
# Epoch 22/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1603 - val_loss: 0.1365
# Epoch 23/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1768 - val_loss: 0.1317
# Epoch 24/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1656 - val_loss: 0.1396
# Epoch 25/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1697 - val_loss: 0.1301
# Epoch 26/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1608 - val_loss: 0.1292
# Epoch 27/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1633 - val_loss: 0.1297
# Epoch 28/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1357 - val_loss: 0.1321
# Epoch 29/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1374 - val_loss: 0.1233
# Epoch 30/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1378 - val_loss: 0.1213
# Epoch 31/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1224 - val_loss: 0.1152
# Epoch 32/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1328 - val_loss: 0.1084
# Epoch 33/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1170 - val_loss: 0.1062
# Epoch 34/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1086 - val_loss: 0.1061
# Epoch 35/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1284 - val_loss: 0.1038
# Epoch 36/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1163 - val_loss: 0.0981
# Epoch 37/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1069 - val_loss: 0.0994
# Epoch 38/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1023 - val_loss: 0.0968
# Epoch 39/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.1118 - val_loss: 0.0968
# Epoch 40/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1083 - val_loss: 0.0939
# Epoch 41/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1050 - val_loss: 0.0948
# Epoch 42/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1033 - val_loss: 0.0958
# Epoch 43/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0957 - val_loss: 0.1011
# Epoch 44/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1046 - val_loss: 0.0922
# Epoch 45/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0995 - val_loss: 0.0916
# Epoch 46/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0978 - val_loss: 0.0935
# Epoch 47/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0867 - val_loss: 0.0908
# Epoch 48/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0954 - val_loss: 0.0907
# Epoch 49/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0972 - val_loss: 0.0912
# Epoch 50/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0955 - val_loss: 0.0881

# %%
"""Plot training and validation loss."""
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend()
plt.show()

# %%
# Make predictions
predicted_sales = model.predict(X)

# Inverse transform to get actual sales values
predicted_sales = scaler.inverse_transform(predicted_sales.reshape(-1, 1))
# Out:
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step

# %%
# Plot the the actual vs predicted results
plt.figure(figsize=(13, 6))
plt.plot(store_data.index[n_step+1:], store_data['Sales'][n_step+1:], 
         label='Actual Sales', color='blue', linestyle='-', linewidth=2)

# Plot the predicted sales
plt.plot(store_data.index[n_step+1:], predicted_sales, 
         label='Predicted Sales', color='orange', linestyle='--', linewidth=2)
plt.title('Actual vs Predicted Sales', fontsize=16)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Sales', fontsize=12)
plt.legend()
plt.show()

# %%
# Calculate evaluation metrics
mse = mean_squared_error(store_data['Sales'][n_step+1:], predicted_sales)
mae = mean_absolute_error(store_data['Sales'][n_step+1:], predicted_sales)
rmse = np.sqrt(mse)
#r2=r2_score(store_data['Sales'][n_step+1:], predicted_sales)
#msle=mean_squared_log_error(store_data['Sales'][n_step+1:], predicted_sales)

print(f'Mean Squared Error (MSE): {mse}')
print(f'Mean Absolute Error (MAE): {mae}')
print(f'Mean Squared Error (RMSE): {rmse}')
# Out:
# Mean Squared Error (MSE): 4920195.686178695
# Mean Absolute Error (MAE): 1527.4895902397081
# Mean Squared Error (RMSE): 2218.1514119145913
