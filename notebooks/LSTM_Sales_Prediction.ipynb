# %%
# Add the parent directory to the system path 
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, mean_squared_error
import os
import sys
sys.path.append(os.path.abspath(os.path.join('..')))

# %%
# importing modules from scripts 
from scripts.dl_modelling import *

# %%
# 1. Load and isolate the Rossmann Store Sales dataset into time series data
df_train = pd.read_csv('../data/clean/train.csv')  # Replace with your actual data file
# Out:
# C:\Users\JO\AppData\Local\Temp\ipykernel_7688\2790484199.py:2: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_train = pd.read_csv('../data/clean/train.csv')  # Replace with your actual data file

# %%
df_train['Date'] = pd.to_datetime(df_train['Date'])
data = df_train[['Date', 'Store', 'Sales']]

# Filter for a specific store (e.g., Store 1)
store_data = data[data['Store'] == 1]
store_data.set_index('Date', inplace=True)
store_data = store_data.resample('D').sum()

# %% [markdown]
# ### 2. Check whether your time Series Data is Stationary

# %%
# Check stationarity for a specific store
# Perform the ADF test

check_stationarity(store_data['Sales'])
# Out:
# ADF Statistic: -4.3681043682
# p-value: 0.0003378835
# Critical Values:
# 	1%: -3.4374778690
# 	5%: -2.8646866842
# 	10%: -2.5684454927
# The time series is stationary

# %%
# Difference the series (store_data is a Series, no need to reference 'Sales')
adf_result = adfuller(store_data['Sales'])
if adf_result[1] >= 0.05:
    store_data['Sales'] = store_data['Sales'].diff().dropna()

# %% [markdown]
# ### 4. Check for autocorrelation and partial autocorrelation of your data

# %%
# Autocorrelation and Partial Autocorrelation plots
fig, ax = plt.subplots(2, 1, figsize=(12, 8))
plot_acf(store_data['Sales'].dropna(), lags=30, ax=ax[0])
plot_pacf(store_data['Sales'].dropna(), lags=30, ax=ax[1])
plt.show()

# %% [markdown]
# ### 5. Transform the time series data into supervised learning data

# %%
# Define time steps
n_step = 30   # number of steps to use for prediction (30 days)
data_scaled = MinMaxScaler(feature_range=(-1, 1)).fit_transform(store_data['Sales'].values.reshape(-1, 1))
X, y = create_supervised_data(data_scaled, n_step)

# Reshape input to be [samples, n_steps, features]
X = X.reshape(X.shape[0], X.shape[1], 1)

# %% [markdown]
# ### 6. Scale your data in the (-1, 1) range

# %%
# Scale the data
scaler = MinMaxScaler(feature_range=(-1, 1))
data_scaled = scaler.fit_transform(store_data['Sales'].values.reshape(-1, 1))

# Create dataset for LSTM
X, y = create_supervised_data(data_scaled, n_step)
X = X.reshape(X.shape[0], X.shape[1], 1)

# %% [markdown]
# ### 7. Build an LSTM Regression model to predict the next sale

# %%
# Build and train the LSTM model
model = build_lstm_model(n_step)

# %%
### Train the model
history = train_lstm_model(model, X, y)
# Out:
# Epoch 1/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 26ms/step - loss: 0.1925 - val_loss: 0.1578
# Epoch 2/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1707 - val_loss: 0.1559
# Epoch 3/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1715 - val_loss: 0.1538
# Epoch 4/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1895 - val_loss: 0.1531
# Epoch 5/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1839 - val_loss: 0.1529
# Epoch 6/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1733 - val_loss: 0.1525
# Epoch 7/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1951 - val_loss: 0.1541
# Epoch 8/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1771 - val_loss: 0.1512
# Epoch 9/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1822 - val_loss: 0.1491
# Epoch 10/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1880 - val_loss: 0.1488
# Epoch 11/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1757 - val_loss: 0.1572
# Epoch 12/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2012 - val_loss: 0.1568
# Epoch 13/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1828 - val_loss: 0.1484
# Epoch 14/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1849 - val_loss: 0.1515
# Epoch 15/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1874 - val_loss: 0.1534
# Epoch 16/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1902 - val_loss: 0.1526
# Epoch 17/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1728 - val_loss: 0.1480
# Epoch 18/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1726 - val_loss: 0.1467
# Epoch 19/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1700 - val_loss: 0.1424
# Epoch 20/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1673 - val_loss: 0.1449
# Epoch 21/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1578 - val_loss: 0.1436
# Epoch 22/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1736 - val_loss: 0.1387
# Epoch 23/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1809 - val_loss: 0.1441
# Epoch 24/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1563 - val_loss: 0.1430
# Epoch 25/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1735 - val_loss: 0.1355
# Epoch 26/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1673 - val_loss: 0.1352
# Epoch 27/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1709 - val_loss: 0.1330
# Epoch 28/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1632 - val_loss: 0.1316
# Epoch 29/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1417 - val_loss: 0.1293
# Epoch 30/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1553 - val_loss: 0.1332
# Epoch 31/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1430 - val_loss: 0.1287
# Epoch 32/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1313 - val_loss: 0.1199
# Epoch 33/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1261 - val_loss: 0.1168
# Epoch 34/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1202 - val_loss: 0.1112
# Epoch 35/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1297 - val_loss: 0.1150
# Epoch 36/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1162 - val_loss: 0.1029
# Epoch 37/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1136 - val_loss: 0.1067
# Epoch 38/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1086 - val_loss: 0.0998
# Epoch 39/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1075 - val_loss: 0.0988
# Epoch 40/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1086 - val_loss: 0.0948
# Epoch 41/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1000 - val_loss: 0.0924
# Epoch 42/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0985 - val_loss: 0.0937
# Epoch 43/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0997 - val_loss: 0.0927
# Epoch 44/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1011 - val_loss: 0.0932
# Epoch 45/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0948 - val_loss: 0.0980
# Epoch 46/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0954 - val_loss: 0.0902
# Epoch 47/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0939 - val_loss: 0.0907
# Epoch 48/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0897 - val_loss: 0.0862
# Epoch 49/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0839 - val_loss: 0.0873
# Epoch 50/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0979 - val_loss: 0.0875

# %%
"""Plot training and validation loss."""
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend()
plt.show()

# %%
# Make predictions
predicted_sales = model.predict(X)

# Inverse transform to get actual sales values
predicted_sales = scaler.inverse_transform(predicted_sales.reshape(-1, 1))
# Out:
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step

# %%
# Plot the the actual vs predicted results
plt.figure(figsize=(13, 6))
plt.plot(store_data.index[n_step+1:], store_data['Sales'][n_step+1:], 
         label='Actual Sales', color='blue', linestyle='-', linewidth=2)

# Plot the predicted sales
plt.plot(store_data.index[n_step+1:], predicted_sales, 
         label='Predicted Sales', color='orange', linestyle='--', linewidth=2)
plt.title('Actual vs Predicted Sales', fontsize=16)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Sales', fontsize=12)
plt.legend()
plt.show()

# %%
# Calculate evaluation metrics
mse = mean_squared_error(store_data['Sales'][n_step+1:], predicted_sales)
mae = mean_absolute_error(store_data['Sales'][n_step+1:], predicted_sales)
rmse = np.sqrt(mse)
#r2=r2_score(store_data['Sales'][n_step+1:], predicted_sales)
#msle=mean_squared_log_error(store_data['Sales'][n_step+1:], predicted_sales)

print(f'Mean Squared Error (MSE): {mse}')
print(f'Mean Absolute Error (MAE): {mae}')
print(f'Mean Squared Error (RMSE): {rmse}')
# Out:
# Mean Squared Error (MSE): 4628106.1264011655
# Mean Absolute Error (MAE): 1493.6823119782198
# Mean Squared Error (RMSE): 2151.30335527121
